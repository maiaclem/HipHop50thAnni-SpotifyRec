# %% [markdown]
# This notebook contains the recommender system.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

# %%
#import data
songs = pd.read_csv('/Users/maiaclemons/Capstone/Data/cleandf.csv')
songs.head()
# Out:
#         artist                              album               track_name  \
# 0    Mobb Deep                       The Infamous  Survival of the Fittest
# 1          Nas                           Illmatic                Represent
# 2   Gang Starr                       Hard To Earn              Mass Appeal
# 3        Big L  Lifestylez Ov Da Poor & Dangerous                Put It On
# 4  Sheek Louch                 Silverback Gorilla           Lottery (Skit)
#
#                  track_id  danceability  energy  key  loudness  mode  \
# 0  7N1Vjtzr1lmmCW9iasQ8YO         0.813   0.703   11    -5.077     0
# 1  6DPrhGVJ1WTZvM9fKptnGe         0.708   0.832    1    -4.964     1
# 2  3lGBvPUgO7MJltUnBlOpe9         0.808   0.726   10    -8.435     0
# 3  6JI5wNWYdBw68GZjOMmgK5         0.711   0.620   11   -10.174     0
# 4  6VjF67azNjUtShTy0Eaz12         0.393   0.641    6   -17.791     1
#
#    speechiness  ...    tempo  duration_ms  time_signature  popularity  \
# 0        0.268  ...   94.828       224533               4          75
# 1        0.318  ...   92.428       252600               4          76
# 2        0.252  ...   96.120       221027               4          61
# 3        0.212  ...  179.817       217627               4          64
# 4        0.453  ...  118.150        31347               4          37
#
#    release_date               artist_id  \
# 0    1995-04-25  6O2zJ0tId7g07yzHtX0yap
# 1    1994-04-19  20qISvAhX20dpIbOOzGK3q
# 2    1994-03-08  5cMgGlA1xGyeAB2ctYlRdZ
# 3    1995-03-28  3CygdxquGHurS7f9LjNLkv
# 4    2008-03-18  14ejEUaU0wE2iAenbbv9b8
#
#                                               genres release_year region  era
# 0  ['east coast hip hop', 'hardcore hip hop', 'hi...         1995   East  90s
# 1  ['conscious hip hop', 'east coast hip hop', 'g...         1994   East  90s
# 2  ['alternative hip hop', 'conscious hip hop', '...         1994   East  90s
# 3  ['contemporary country', 'country', 'country d...         1995  Other  90s
# 4                               ['hardcore hip hop']         2008  Other  00s
#
# [5 rows x 23 columns]

# %%
#encoding region and era with get dummies

eras = pd.get_dummies(songs['era'], prefix='era')
region = pd.get_dummies(songs['region'], prefix='region')

# adding encoded columns to songs
encoded = pd.concat([songs, eras, region], axis=1)

# %%
#dropping columns not needed for recommender
encoded.drop(columns=['era','region','artist','track_id','release_date','album','genres','artist_id'], inplace=True)

# %%
#make track name the index 
encoded.set_index('track_name', inplace=True)

# %%
encoded.head()
# Out:
#                          danceability  energy  key  loudness  mode  \
# track_name
# Survival of the Fittest         0.813   0.703   11    -5.077     0
# Represent                       0.708   0.832    1    -4.964     1
# Mass Appeal                     0.808   0.726   10    -8.435     0
# Put It On                       0.711   0.620   11   -10.174     0
# Lottery (Skit)                  0.393   0.641    6   -17.791     1
#
#                          speechiness  instrumentalness  liveness  valence  \
# track_name
# Survival of the Fittest        0.268          0.000001     0.237    0.241
# Represent                      0.318          0.000003     0.189    0.618
# Mass Appeal                    0.252          0.276000     0.129    0.616
# Put It On                      0.212          0.000000     0.134    0.805
# Lottery (Skit)                 0.453          0.000000     0.508    0.870
#
#                            tempo  ...  release_year  era_00s  era_70s-80s  \
# track_name                        ...
# Survival of the Fittest   94.828  ...          1995        0            0
# Represent                 92.428  ...          1994        0            0
# Mass Appeal               96.120  ...          1994        0            0
# Put It On                179.817  ...          1995        0            0
# Lottery (Skit)           118.150  ...          2008        1            0
#
#                          era_90s  era_Current  region_East  region_Midwest  \
# track_name
# Survival of the Fittest        1            0            1               0
# Represent                      1            0            1               0
# Mass Appeal                    1            0            1               0
# Put It On                      1            0            0               0
# Lottery (Skit)                 0            0            0               0
#
#                          region_Other  region_South  region_West
# track_name
# Survival of the Fittest             0             0            0
# Represent                           0             0            0
# Mass Appeal                         0             0            0
# Put It On                           1             0            0
# Lottery (Skit)                      1             0            0
#
# [5 rows x 23 columns]

# %%
#checking data types to make sure they're all numerical
encoded.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# time_signature        int64
# popularity            int64
# release_year          int64
# era_00s               uint8
# era_70s-80s           uint8
# era_90s               uint8
# era_Current           uint8
# region_East           uint8
# region_Midwest        uint8
# region_Other          uint8
# region_South          uint8
# region_West           uint8
# dtype: object

# %%
#convert df to sparse matrix
sparse_matrix = sparse.csr_matrix(encoded.values)

# %%
#calculate cosine similarity matrix
similarity_matrix = cosine_similarity(sparse_matrix)

# %%
similarity_matrix
# Out:
# array([[1.        , 0.99999951, 0.99999999, ..., 0.99999923, 0.99999991,
#         0.99999983],
#        [0.99999951, 1.        , 0.99999936, ..., 0.99999993, 0.99999967,
#         0.99999984],
#        [0.99999999, 0.99999936, 1.        , ..., 0.99999907, 0.99999989,
#         0.99999977],
#        ...,
#        [0.99999923, 0.99999993, 0.99999907, ..., 1.        , 0.99999953,
#         0.99999975],
#        [0.99999991, 0.99999967, 0.99999989, ..., 0.99999953, 1.        ,
#         0.99999996],
#        [0.99999983, 0.99999984, 0.99999977, ..., 0.99999975, 0.99999996,
#         1.        ]])

# %%
def get_track_name_from_index(index):
    return songs[songs.index == index]["track_name"].values[0]

target_index = 765 

# Get the indices of the top similar songs
similar_songs_indices = np.argsort(similarity_matrix[target_index])[::-1][:15]

# Print the recommended songs
for song_index in similar_songs_indices:
    song_title = get_track_name_from_index(song_index)
    print(song_title)
# Out:
# Feeling Myself
# Life Is Good (feat. Drake)
# F*ck Up Some Commas
# Stay Fly
# I Mean It (feat. Remo)
# Amazing
# Fashion Killa
# Portland
# The Show Goes On
# Gossip Folks (feat. Ludacris)
# EVERY CHANCE I GET (feat. Lil Baby & Lil Durk)
# LsD
# Headlines
# Rich Flex
# I'm N Luv (Wit a Stripper) (feat. Mike Jones)
